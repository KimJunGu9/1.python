# %% [markdown]
# <a href="https://colab.research.google.com/github/KimJunGu9/1.python/blob/main/12_%EC%82%AC%EC%9A%A9%EC%9E%90_%EC%A0%95%EC%9D%98_%ED%95%A8%EC%88%98.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **1. 함수**

# %% [markdown]
# * 변수 x, y에 대해 x값이 정해지면 그에 따라 y값이 결정되는 것
# * 반복적으로 사용되는 가치 있는 부분을 묶어서 하나의 집합으로 만듬
# * 코드를 재활용하기 위한 목적

# %% [markdown]
# ### **1-1. 이름만 있는 함수**
#
# ```
# def 함수명():
#   함수가 호출되면 실행할 문장
#   ...
# ```
#
# ```
# 함수명() # 호출
# ```

# %%
def func1():
  print('처음으로 만드는 함수!')

# %%
func1()
func1()
# Out:
# 처음으로 만드는 함수!
# 처음으로 만드는 함수!

# %%
for i in range(5):
  func1()
# Out:
# 처음으로 만드는 함수!
# 처음으로 만드는 함수!
# 처음으로 만드는 함수!
# 처음으로 만드는 함수!
# 처음으로 만드는 함수!

# %% [markdown]
# ### **1-2. 매개변수(parameter)가 있는 함수**
#
# ```
# def 함수명(변수1, 변수2...):         # 변수1, 변수2는 매개변수
#   함수가 호출되면 실행할 문장
#   ...
# ```
#
# ```
# 함수명(값1, 값2 ..) # 호출
# ```

# %% [markdown]
# ![123.png](data:image/png;base64,...)

# %%
def func2(num):
  # print('입력받은 숫자 : %d' %num)
  print(f'입력받은 숫자 : {num}')

# %%
func2(10)
func2(30)
# Out:
# 입력받은 숫자 : 10
# 입력받은 숫자 : 30

# %%
def func3(start, end):
  sum = 0
  for i in range(start, end + 1, 1):
    sum += i
  # print(start, "부터 ", end, "까지의 합 : ", sum)
  print(f'{start}부터 {end} 까지의 합 : {sum}')

# %%
func3(1,10)
func3(1,100)
func3(10,50)
# Out:
# 1부터 10 까지의 합 : 55
# 1부터 100 까지의 합 : 5050
# 10부터 50 까지의 합 : 1230

# %% [markdown]
# ### **1-3. 리턴값이 있는 함수**

# %% [markdown]
# ```
# def 함수명(변수1, 변수2, ...):
#   함수가 호출되면 실행할 문장
#   ...
#   return 값
# ```
#
# ```
# 변수 = 함수명(값1, 값2..) # 호출
# ```

# %% [markdown]
# ![1234.png](data:image/png;base64,...)

# %% [markdown]
# ![12345.png](data:image/png;base64,...)

# %% [markdown]
# 1. 함수를 호출하게되면 이 함수를 같은 이름의 함수에 호출한다.
# 2. 호출하는데 변수는 같아야한다.
# 3. 계산을 하고나서 결과가 나오면 그 값을 return 옆에 있는 값에 넣어준다.
# 4. 그럼 return에 의한 키워드는 이 함수가 불려졌던 곳에 값이 돌아가게 되고, 그 값을 변수에다가 저장한다.

# %%
def func4():
  return '❤️'

# %%
print(func4())
# Out:
# ❤️

# %%
present = func4()
print(present)
# Out:
# ❤️

# %%
def func5(num1, num2):
  return num1 + num2

# %%
# ver1.
print(func5(10,5))
# Out:
# 15

# %%
# ver2.
result = func5(10,5)
print(f'두 수의 합 : {result}')
# Out:
# 두 수의 합 : 15

# %% [markdown]
# ### **1-4. 디폴트 매개변수**
# ```
# def 함수명(변수1, 변수2=값2 ..):       # 변수에 값을 미리 저장해놓음. 데이터를 넣어도되고 안넣어도 된다.
#   함수를 호출하면 실행할 문장
#   ...
#   return 값
# ```
#
# ```
#   함수명(값1) # 호출1
#   함수명(값1, 값2...) # 호출2
# ```

# %%
def func6(num1, num2 = 0):
  return num1 * num2

# %%
print(func6(10))
print(func6(10,3))
# Out:
# 0
# 30

# %% [markdown]
# ### **1-5. 매개변수의 개수가 가변적인 함수**
#
# ```
# def 함수명(*변수):
#   함수가 호출되면 실행할 문장
#   ...
#   return 값
# ```
#
# ```
# 함수명(값1) # 호출1
# 함수명(값1, 값2, ...) # 호출2
# ```
#
# > 매개변수는 함수안에서 튜플형태로 사용

# %%
def func7(*args):
  result = 0
  for i in args:
    result += i
  return result

# %%
print(func7(10))
print(func7(10,30,20,70,50))
# Out:
# 10
# 180

# %% [markdown]
# ### **1-6. 매개변수를 딕셔너리 구조로 전달받는 함수**
#
# ```
# def 함수명(**매개변수):
#   함수가 호출되면 실행할 문장
#   ...
#   return 값
# ```
#
# ```
# 함수명(변수1=값1, 변수2=값2 ..) # 호출
# ```

# %%
def func8(**args):
  return args

user= func8(userid='apple', name='김사과', age = 20)
print(user)
# Out:
# {'userid': 'apple', 'name': '김사과', 'age': 20}

# %% [markdown]
# ![111.png](data:image/png;base64,...)

# %% [markdown]
# ### **1-7. 리턴값이 여러개인 함수**

# %% [markdown]
# ```
# def 함수명(변수1, 변수2 ..):
#   함수가 호출되면 실행될 문장
#   ...
#   return 값1, 값2, ..
# ```
#
# ```
# 변수1, 변수2, ... = 함수명(값1, 값2, ..)  # 호출
# ```

# %% [markdown]
# ![2222.png](data:image/png;base64,...)

# %%
def func9(num1, num2):
  return num1 + num2, num1 - num2, num1 * num2, num1 / num2

# %%
result1, result2, result3, result4 = func9(10,3)
print(result1, result2, result3, result4)
# Out:
# 13 7 30 3.3333333333333335

# %% [markdown]
# ### **문제.**
# 데이터 90, 80, 50, 100, 70을 매개변수로 전달해서 최대값, 최소값을 출력하는 함수를 만들어 활용해보자
# (단, return을 사용, 내장함수를 사용하지 않음)

# %%
def maxmin(*args):  # (90, 80 , 50, 100, 70)
  max, min = args[0], args[0]
  for i in args:
    if max < i:
      max = i
    
    if min > i:
      min = i
  return max, min

# %%
max, min = maxmin(90, 80 , 50, 100, 70)
print('최대값 : ', max)
print('최소값 : ', min)
# Out:
# 최대값 :  100
# 최소값 :  50

# %%
max, min = maxmin(123,21,4,5346,234,12,1,5,6453)
print('최대값 : ', max)
print('최소값 : ', min)
# Out:
# 최대값 :  6453
# 최소값 :  1

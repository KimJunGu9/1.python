# %% [markdown]
# <a href="https://colab.research.google.com/github/KimJunGu9/1.python/blob/main/16_%EC%8A%A4%ED%8E%98%EC%85%9C_%EB%A9%94%EC%86%8C%EB%93%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **1. 스페셜 메소드(Special Method)**

# %% [markdown]
# * __로 시작해서 __로 끝나는 특수함수
# * 해당 메소드들을 구현하면 커스텀 객체에 여러가지 파이썬 내장 함수나 연산자를 적용 가능
# * 오버라이딩 가능한 함수 목록은 아래 링크에서 확인
# (https://docs.python.org/3/reference/datamodel.html)

# %%
class Point:
  def __init__(self, x, y):
    self.x = x
    self.y = y

  def print_pt(self):
    print('({}, {})'.format(self.x, self.y)) # (3, 4)

  def __str__(self):  # str()
    return ('({}, {})'.format(self.x, self.y)) 
    # 메모리주소가 나오는게아니라 ( ?, ? ) 형태로 나온다. (기능이 오버라이딩형태로 나옴)


  def __add__(self, pt): # 더하기를 add에 덮어써서 add가 덧셈을 오버라이딩 하는 
    new_x = self.x + pt.x
    new_y = self.y + pt.y
    return Point(new_x, new_y)

  def __sub__(self, pt):
    new_x = self.x - pt.x
    new_y = self.y - pt.y
    return Point(new_x, new_y)

  def __mul__(self, m):
    return Point(self.x * m, self.y * m)

  def __len__(self):
    return self.x ** 2 + self.y ** 2

  def __getitem__(self, index):
    if index == 0:
      return self.x
    elif index == 1:
      return self.y
    else:
      return -1

# %%
p1 = Point(3, 4)
print(p1)
print(str(p1))
p1.print_pt()
# Out:
# (3, 4)
# (3, 4)
# (3, 4)

# %%
p2 = Point(5, 8)
print(p2)

p3 = p1 + p2
print(p3)
# Out:
# (5, 8)
# (8, 12)

# %% [markdown]
# ![927.png](data:image/png;base64,...)

# %%
p4 = p1 - p2
print(p4)
# Out:
# (-2, -4)

# %%
p5 = p1 * 3
print(p5)
# Out:
# (9, 12)

# %%
print(len(p1))
# Out:
# 25

# %%
# p1 = Point(3, 4)
print(p1[0])
print(p1[1])
print(p1[5])
# Out:
# 3
# 4
# -1
